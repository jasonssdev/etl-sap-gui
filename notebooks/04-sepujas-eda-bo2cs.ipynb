# %%
import pandas as pd
import os

# %%
current_path = os.getcwd()
print(current_path)
# Out:
# c:\Users\sepujas\Dev\mat\notebooks

# %%
base_path = os.path.abspath(os.path.join(current_path, os.pardir))
print(base_path)
# Out:
# c:\Users\sepujas\Dev\mat

# %%
bo2cs_file_path = os.path.join(base_path, 'data', 'raw', 'tbl_bo2cs.txt')
print(bo2cs_file_path)
# Out:
# c:\Users\sepujas\Dev\mat\data\raw\tbl_bo2cs.txt

# %%
bo2cs_preprocessed_path = os.path.join(base_path, 'data', 'preprocessed', 'tbl_bo2cs.csv')
print(bo2cs_preprocessed_path)
# Out:
# c:\Users\sepujas\Dev\mat\data\preprocessed\tbl_bo2cs.csv

# %%
df_bo2cs = pd.read_csv(bo2cs_file_path, sep='\t', skiprows=1, encoding='latin1')
df_bo2cs.head()
# Out:
# C:\Users\sepujas\AppData\Local\Temp\ipykernel_16280\608863967.py:1: DtypeWarning: Columns (1,5,7,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bo2cs = pd.read_csv(bo2cs_file_path, sep='\t', skiprows=1, encoding='latin1')
#    Unnamed: 0 Unnamed: 1   SOrg. SaTy    Sales Doc.   Sold-to  \
# 0         NaN        NaN  8650.0  ZRO  7.210671e+09  15919708
# 1         NaN        NaN  8650.0  ZRO  7.211113e+09  15917697
# 2         NaN        NaN  8650.0  ZRO  7.211178e+09  23023419
# 3         NaN        NaN  8650.0  ZRO  7.211204e+09  23023419
# 4         NaN        NaN  8650.0  ZRO  7.211195e+09  23106139
#
#                          Name 1   Ship-to                 Name 1.1  CustLoy  \
# 0                   HUELQUEN SA  15919708              HUELQUEN SA      NaN
# 1  EMPRESA CONSTRUCTORA BRAVO E  24583539  242 EDIFICIO CONTEMPORA      NaN
# 2   CONSORCIO VALLE HERMOSO S.A  23023498    EMBALSE VALLE HERMOSO      NaN
# 3   CONSORCIO VALLE HERMOSO S.A  23023498    EMBALSE VALLE HERMOSO      NaN
# 4  AMPUERO Y COFRE CONSTRUCCION  24958240               CONDOMINIO      NaN
#
#   Foc.Cust   Territory  Created On Typ  Material  \
# 0      NaN  TCL5100010  20.12.2017  X6  301998.0
# 1        X  TCL3400012  16.02.2018  ND  203086.0
# 2      NaN  TCL2600018  28.02.2018  ND  203086.0
# 3      NaN  TCL2600018  28.02.2018  ND  203086.0
# 4      NaN  TCL3100010  01.03.2018  ND  203086.0
#
#                        Item Description Order Qty Corr.qty ConfirmQty  SU  \
# 0             Tapón de cierre R3/8 rojo         1        1          1  PC
# 1  Grasa Turmogrease BIO LC 1302 (50ml)         1        1          1  PC
# 2  Grasa Turmogrease BIO LC 1302 (50ml)         1        1          1  PC
# 3  Grasa Turmogrease BIO LC 1302 (50ml)         1        1          1  PC
# 4  Grasa Turmogrease BIO LC 1302 (50ml)         1        1          1  PC
#
#         BO value Crcy   InitReqDt    promised  Mat.Av.Dt.    Dlv.Date DS   DB  \
# 0            NaN  CLP  20.12.2017  04.01.2018  06.01.2021  06.01.2021  A  NaN
# 1            NaN  CLP  16.02.2018  07.03.2018  06.03.2018  07.03.2018  A   06
# 2            NaN  CLP  28.02.2018  06.03.2018  05.03.2018  06.03.2018  A   06
# 3            NaN  CLP  28.02.2018  06.03.2018  05.03.2018  06.03.2018  A   06
# 4            NaN  CLP  01.03.2018  06.03.2018  05.03.2018  06.03.2018  A   06
#
#   BOstatus BO     BO status changed GM unc.   Description Shp. Cond.   Route  \
# 0   Unproc  X   28.12.2017 16:01:41  A  NaN  REPAIR PARTS         0F  ZCL913
# 1   Unproc  X   06.03.2018 17:57:03  A  NaN  REPAIR PARTS         0E  ZCL915
# 2   Unproc  X   05.03.2018 15:35:50  A  NaN  REPAIR PARTS         0E  ZCL121
# 3   Unproc  X   05.03.2018 14:51:44  A  NaN  REPAIR PARTS         0E  ZCL121
# 4   Unproc  X   05.03.2018 18:38:15  A  NaN  REPAIR PARTS         0E  ZCL915
#
#    Req.dlv.dt
# 0  20.12.2017
# 1  16.02.2018
# 2  28.02.2018
# 3  28.02.2018
# 4  01.03.2018

# %%
df_bo2cs.dtypes
# Out:
# Unnamed: 0              float64
# Unnamed: 1               object
# SOrg.                   float64
# SaTy                     object
# Sales Doc.              float64
# Sold-to                  object
# Name 1                   object
# Ship-to                  object
# Name 1.1                 object
# CustLoy                 float64
# Foc.Cust                 object
# Territory                object
# Created On               object
# Typ                      object
# Material                float64
# Item Description         object
# Order Qty                object
# Corr.qty                 object
# ConfirmQty               object
# SU                       object
#       BO value           object
# Crcy                     object
# InitReqDt                object
# promised                 object
# Mat.Av.Dt.               object
# Dlv.Date                 object
# DS                       object
# DB                       object
# BOstatus                 object
# BO                       object
#    BO status changed     object
# GM                       object
# unc.                     object
# Description              object
# Shp. Cond.               object
# Route                    object
# Req.dlv.dt               object
# dtype: object

# %%
unnamed_columns = [col for col in df_bo2cs.columns if 'Unnamed:' in col]

print("Columns with 'Unnamed:' in their title:")
for col in unnamed_columns:
    print(col)
# Out:
# Columns with 'Unnamed:' in their title:
# Unnamed: 0
# Unnamed: 1

# %%
df_bo2cs.drop(columns=unnamed_columns, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
df_bo2cs.head()
# Out:
#     SOrg. SaTy    Sales Doc.   Sold-to                        Name 1  \
# 0  8650.0  ZRO  7.210671e+09  15919708                   HUELQUEN SA
# 1  8650.0  ZRO  7.211113e+09  15917697  EMPRESA CONSTRUCTORA BRAVO E
# 2  8650.0  ZRO  7.211178e+09  23023419   CONSORCIO VALLE HERMOSO S.A
# 3  8650.0  ZRO  7.211204e+09  23023419   CONSORCIO VALLE HERMOSO S.A
# 4  8650.0  ZRO  7.211195e+09  23106139  AMPUERO Y COFRE CONSTRUCCION
#
#     Ship-to                 Name 1.1  CustLoy Foc.Cust   Territory  \
# 0  15919708              HUELQUEN SA      NaN      NaN  TCL5100010
# 1  24583539  242 EDIFICIO CONTEMPORA      NaN        X  TCL3400012
# 2  23023498    EMBALSE VALLE HERMOSO      NaN      NaN  TCL2600018
# 3  23023498    EMBALSE VALLE HERMOSO      NaN      NaN  TCL2600018
# 4  24958240               CONDOMINIO      NaN      NaN  TCL3100010
#
#    Created On Typ  Material                      Item Description Order Qty  \
# 0  20.12.2017  X6  301998.0             Tapón de cierre R3/8 rojo         1
# 1  16.02.2018  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1
# 2  28.02.2018  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1
# 3  28.02.2018  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1
# 4  01.03.2018  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1
#
#   Corr.qty ConfirmQty  SU       BO value Crcy   InitReqDt    promised  \
# 0        1          1  PC            NaN  CLP  20.12.2017  04.01.2018
# 1        1          1  PC            NaN  CLP  16.02.2018  07.03.2018
# 2        1          1  PC            NaN  CLP  28.02.2018  06.03.2018
# 3        1          1  PC            NaN  CLP  28.02.2018  06.03.2018
# 4        1          1  PC            NaN  CLP  01.03.2018  06.03.2018
#
#    Mat.Av.Dt.    Dlv.Date DS   DB BOstatus BO     BO status changed GM unc.  \
# 0  06.01.2021  06.01.2021  A  NaN   Unproc  X   28.12.2017 16:01:41  A  NaN
# 1  06.03.2018  07.03.2018  A   06   Unproc  X   06.03.2018 17:57:03  A  NaN
# 2  05.03.2018  06.03.2018  A   06   Unproc  X   05.03.2018 15:35:50  A  NaN
# 3  05.03.2018  06.03.2018  A   06   Unproc  X   05.03.2018 14:51:44  A  NaN
# 4  05.03.2018  06.03.2018  A   06   Unproc  X   05.03.2018 18:38:15  A  NaN
#
#     Description Shp. Cond.   Route  Req.dlv.dt
# 0  REPAIR PARTS         0F  ZCL913  20.12.2017
# 1  REPAIR PARTS         0E  ZCL915  16.02.2018
# 2  REPAIR PARTS         0E  ZCL121  28.02.2018
# 3  REPAIR PARTS         0E  ZCL121  28.02.2018
# 4  REPAIR PARTS         0E  ZCL915  01.03.2018

# %%
df_bo2cs.shape
# Out:
# (23569, 35)

# %%
df_bo2cs.dtypes
# Out:
# SOrg.                   float64
# SaTy                     object
# Sales Doc.              float64
# Sold-to                  object
# Name 1                   object
# Ship-to                  object
# Name 1.1                 object
# CustLoy                 float64
# Foc.Cust                 object
# Territory                object
# Created On               object
# Typ                      object
# Material                float64
# Item Description         object
# Order Qty                object
# Corr.qty                 object
# ConfirmQty               object
# SU                       object
#       BO value           object
# Crcy                     object
# InitReqDt                object
# promised                 object
# Mat.Av.Dt.               object
# Dlv.Date                 object
# DS                       object
# DB                       object
# BOstatus                 object
# BO                       object
#    BO status changed     object
# GM                       object
# unc.                     object
# Description              object
# Shp. Cond.               object
# Route                    object
# Req.dlv.dt               object
# dtype: object

# %%
column_titles = df_bo2cs.columns.tolist()
column_titles
# Out:
# ['SOrg.',
#  'SaTy',
#  'Sales Doc.',
#  'Sold-to',
#  'Name 1',
#  'Ship-to',
#  'Name 1.1',
#  'CustLoy',
#  'Foc.Cust',
#  'Territory',
#  'Created On',
#  'Typ',
#  'Material',
#  'Item Description',
#  'Order Qty',
#  'Corr.qty',
#  'ConfirmQty',
#  'SU',
#  '      BO value',
#  'Crcy',
#  'InitReqDt',
#  'promised',
#  'Mat.Av.Dt.',
#  'Dlv.Date',
#  'DS',
#  'DB',
#  'BOstatus',
#  'BO',
#  '   BO status changed',
#  'GM',
#  'unc.',
#  'Description',
#  'Shp. Cond.',
#  'Route',
#  'Req.dlv.dt']

# %%
new_column_titles = {col: col.strip().replace(' ', '_').replace('-','_').replace('.','') for col in column_titles}

# %%
df_bo2cs.rename(columns=new_column_titles, inplace=True)

# %%
df_bo2cs.columns.tolist()
# Out:
# ['SOrg',
#  'SaTy',
#  'Sales_Doc',
#  'Sold_to',
#  'Name_1',
#  'Ship_to',
#  'Name_11',
#  'CustLoy',
#  'FocCust',
#  'Territory',
#  'Created_On',
#  'Typ',
#  'Material',
#  'Item_Description',
#  'Order_Qty',
#  'Corrqty',
#  'ConfirmQty',
#  'SU',
#  'BO_value',
#  'Crcy',
#  'InitReqDt',
#  'promised',
#  'MatAvDt',
#  'DlvDate',
#  'DS',
#  'DB',
#  'BOstatus',
#  'BO',
#  'BO_status_changed',
#  'GM',
#  'unc',
#  'Description',
#  'Shp_Cond',
#  'Route',
#  'Reqdlvdt']

# %%
df_bo2cs.dtypes
# Out:
# SOrg                 float64
# SaTy                  object
# Sales_Doc            float64
# Sold_to               object
# Name_1                object
# Ship_to               object
# Name_11               object
# CustLoy              float64
# FocCust               object
# Territory             object
# Created_On            object
# Typ                   object
# Material             float64
# Item_Description      object
# Order_Qty             object
# Corrqty               object
# ConfirmQty            object
# SU                    object
# BO_value              object
# Crcy                  object
# InitReqDt             object
# promised              object
# MatAvDt               object
# DlvDate               object
# DS                    object
# DB                    object
# BOstatus              object
# BO                    object
# BO_status_changed     object
# GM                    object
# unc                   object
# Description           object
# Shp_Cond              object
# Route                 object
# Reqdlvdt              object
# dtype: object

# %%
pd.set_option('display.max_columns', None)

# %%
df_bo2cs.head()
# Out:
#      SOrg SaTy     Sales_Doc   Sold_to                        Name_1  \
# 0  8650.0  ZRO  7.210671e+09  15919708                   HUELQUEN SA
# 1  8650.0  ZRO  7.211113e+09  15917697  EMPRESA CONSTRUCTORA BRAVO E
# 2  8650.0  ZRO  7.211178e+09  23023419   CONSORCIO VALLE HERMOSO S.A
# 3  8650.0  ZRO  7.211204e+09  23023419   CONSORCIO VALLE HERMOSO S.A
# 4  8650.0  ZRO  7.211195e+09  23106139  AMPUERO Y COFRE CONSTRUCCION
#
#     Ship_to                  Name_11  CustLoy FocCust   Territory  Created_On  \
# 0  15919708              HUELQUEN SA      NaN     NaN  TCL5100010  20.12.2017
# 1  24583539  242 EDIFICIO CONTEMPORA      NaN       X  TCL3400012  16.02.2018
# 2  23023498    EMBALSE VALLE HERMOSO      NaN     NaN  TCL2600018  28.02.2018
# 3  23023498    EMBALSE VALLE HERMOSO      NaN     NaN  TCL2600018  28.02.2018
# 4  24958240               CONDOMINIO      NaN     NaN  TCL3100010  01.03.2018
#
#   Typ  Material                      Item_Description Order_Qty  Corrqty  \
# 0  X6  301998.0             Tapón de cierre R3/8 rojo         1        1
# 1  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1        1
# 2  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1        1
# 3  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1        1
# 4  ND  203086.0  Grasa Turmogrease BIO LC 1302 (50ml)         1        1
#
#   ConfirmQty  SU BO_value Crcy   InitReqDt    promised     MatAvDt  \
# 0          1  PC      NaN  CLP  20.12.2017  04.01.2018  06.01.2021
# 1          1  PC      NaN  CLP  16.02.2018  07.03.2018  06.03.2018
# 2          1  PC      NaN  CLP  28.02.2018  06.03.2018  05.03.2018
# 3          1  PC      NaN  CLP  28.02.2018  06.03.2018  05.03.2018
# 4          1  PC      NaN  CLP  01.03.2018  06.03.2018  05.03.2018
#
#       DlvDate DS   DB BOstatus BO     BO_status_changed GM  unc   Description  \
# 0  06.01.2021  A  NaN   Unproc  X   28.12.2017 16:01:41  A  NaN  REPAIR PARTS
# 1  07.03.2018  A   06   Unproc  X   06.03.2018 17:57:03  A  NaN  REPAIR PARTS
# 2  06.03.2018  A   06   Unproc  X   05.03.2018 15:35:50  A  NaN  REPAIR PARTS
# 3  06.03.2018  A   06   Unproc  X   05.03.2018 14:51:44  A  NaN  REPAIR PARTS
# 4  06.03.2018  A   06   Unproc  X   05.03.2018 18:38:15  A  NaN  REPAIR PARTS
#
#   Shp_Cond   Route    Reqdlvdt
# 0       0F  ZCL913  20.12.2017
# 1       0E  ZCL915  16.02.2018
# 2       0E  ZCL121  28.02.2018
# 3       0E  ZCL121  28.02.2018
# 4       0E  ZCL915  01.03.2018

# %%
df_bo2cs['SOrg'] = df_bo2cs['SOrg'].fillna(0).astype(int).astype(str).str.strip()
df_bo2cs['SaTy'] = df_bo2cs['SaTy'].astype(str).str.strip()
df_bo2cs['Sales_Doc'] = df_bo2cs['Sales_Doc'].fillna(0).astype(int).astype(str).str.strip()
df_bo2cs['Sold_to'] = df_bo2cs['Sold_to'].astype(str).str.strip()
df_bo2cs['Name_1'] = df_bo2cs['Name_1'].astype(str).str.strip()
df_bo2cs['CustLoy'] = df_bo2cs['CustLoy'].astype(str).str.strip()
df_bo2cs['FocCust'] = df_bo2cs['FocCust'].astype(str).str.strip()
df_bo2cs['Territory'] = df_bo2cs['Territory'].astype(str).str.strip()
df_bo2cs['Created_On'] = pd.to_datetime(df_bo2cs['Created_On'], errors="coerce", format='%d.%m.%Y')
df_bo2cs['Typ'] = df_bo2cs['Typ'].astype(str).str.strip()
df_bo2cs['Material'] = df_bo2cs['Material'].fillna(0).astype(int).astype(str).str.strip()
df_bo2cs['Item_Description'] = df_bo2cs['Item_Description'].astype(str).str.strip()
df_bo2cs['Order_Qty'] = df_bo2cs['Order_Qty'].astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_bo2cs['Corrqty'] = df_bo2cs['Corrqty'].astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_bo2cs['ConfirmQty'] = df_bo2cs['ConfirmQty'].astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_bo2cs['SU'] = df_bo2cs['SU'].astype(str).str.strip()
df_bo2cs['BO_value'] = df_bo2cs['BO_value'].astype(str).str.strip()
df_bo2cs['Crcy'] = df_bo2cs['Crcy'].astype(str).str.strip()
df_bo2cs['InitReqDt'] = pd.to_datetime(df_bo2cs['InitReqDt'], errors="coerce", format='%d.%m.%Y')
df_bo2cs['promised'] = pd.to_datetime(df_bo2cs['promised'], errors="coerce", format='%d.%m.%Y')
df_bo2cs['MatAvDt'] = pd.to_datetime(df_bo2cs['MatAvDt'], errors="coerce", format='%d.%m.%Y')
df_bo2cs['DlvDate'] = pd.to_datetime(df_bo2cs['DlvDate'], errors="coerce", format='%d.%m.%Y')
df_bo2cs['DS'] = df_bo2cs['DS'].astype(str).str.strip()
df_bo2cs['DB'] = df_bo2cs['DB'].astype(str).str.strip()
df_bo2cs['BOstatus'] = df_bo2cs['BOstatus'].astype(str).str.strip()
df_bo2cs['BO'] = df_bo2cs['BO'].astype(str).str.strip()
df_bo2cs['BO_status_changed'] = pd.to_datetime(df_bo2cs['BO_status_changed'], errors="coerce", format='%d.%m.%Y')
df_bo2cs['GM'] = df_bo2cs['GM'].astype(str).str.strip()
df_bo2cs['unc'] = df_bo2cs['unc'].astype(str).str.strip()
df_bo2cs['Description'] = df_bo2cs['Description'].astype(str).str.strip()
df_bo2cs['Shp_Cond'] == df_bo2cs['Item_Description'].astype(str).str.strip()
df_bo2cs['Route'] = df_bo2cs['Route'].astype(str).str.strip()
df_bo2cs['Reqdlvdt'] = pd.to_datetime(df_bo2cs['Reqdlvdt'], errors="coerce", format='%d.%m.%Y')

# %%
df_bo2cs.dtypes
# Out:
# SOrg                         object
# SaTy                         object
# Sales_Doc                    object
# Sold_to                      object
# Name_1                       object
# Ship_to                      object
# Name_11                      object
# CustLoy                      object
# FocCust                      object
# Territory                    object
# Created_On           datetime64[ns]
# Typ                          object
# Material                     object
# Item_Description             object
# Order_Qty                   float64
# Corrqty                     float64
# ConfirmQty                  float64
# SU                           object
# BO_value                     object
# Crcy                         object
# InitReqDt            datetime64[ns]
# promised             datetime64[ns]
# MatAvDt              datetime64[ns]
# DlvDate              datetime64[ns]
# DS                           object
# DB                           object
# BOstatus                     object
# BO                           object
# BO_status_changed    datetime64[ns]
# GM                           object
# unc                          object
# Description                  object
# Shp_Cond                     object
# Route                        object
# Reqdlvdt             datetime64[ns]
# dtype: object

# %%
df_bo2cs['key_material'] = df_bo2cs['SOrg'] + '/' + df_bo2cs['Material']
df_bo2cs['key_material'] = df_bo2cs['key_material'].astype(str).str.strip()

# %%
df_bo2cs.to_csv(bo2cs_preprocessed_path, index=False)

# %%
df_bo2cs.dtypes
# Out:
# SOrg                         object
# SaTy                         object
# Sales_Doc                    object
# Sold_to                      object
# Name_1                       object
# Ship_to                      object
# Name_11                      object
# CustLoy                      object
# FocCust                      object
# Territory                    object
# Created_On           datetime64[ns]
# Typ                          object
# Material                     object
# Item_Description             object
# Order_Qty                   float64
# Corrqty                     float64
# ConfirmQty                  float64
# SU                           object
# BO_value                     object
# Crcy                         object
# InitReqDt            datetime64[ns]
# promised             datetime64[ns]
# MatAvDt              datetime64[ns]
# DlvDate              datetime64[ns]
# DS                           object
# DB                           object
# BOstatus                     object
# BO                           object
# BO_status_changed    datetime64[ns]
# GM                           object
# unc                          object
# Description                  object
# Shp_Cond                     object
# Route                        object
# Reqdlvdt             datetime64[ns]
# key_material                 object
# dtype: object

# %%
print(df_bo2cs.iloc[:, [1, 5, 7, 18]].head())
# Out:
#   SaTy   Ship_to CustLoy BO_value
# 0  ZRO  15919708     nan      nan
# 1  ZRO  24583539     nan      nan
# 2  ZRO  23023498     nan      nan
# 3  ZRO  23023498     nan      nan
# 4  ZRO  24958240     nan      nan
