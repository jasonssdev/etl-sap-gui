# %%
import pandas as pd
import os

# %%
current_path = os.getcwd()
print(current_path)
# Out:
# c:\Users\sepujas\Dev\mat\notebooks

# %%
base_path = os.path.abspath(os.path.join(current_path, os.pardir))
print(base_path)
# Out:
# c:\Users\sepujas\Dev\mat

# %%
material_moar_path = os.path.join(base_path, 'data', 'raw', 'tbl_material_8750.txt')
print(material_moar_path)
# Out:
# c:\Users\sepujas\Dev\mat\data\raw\tbl_material_8750.txt

# %%
material_8750_preprocessed_path = os.path.join(base_path, 'data', 'preprocessed', 'tbl_material_8750.csv')
print(material_8750_preprocessed_path)
# Out:
# c:\Users\sepujas\Dev\mat\data\preprocessed\tbl_material_8750.csv

# %%
os.path.exists(material_moar_path)
# Out:
# True

# %%
os.path.isfile(material_moar_path)
# Out:
# True

# %%
df_material_moar = pd.read_csv(material_moar_path, sep='\t', skiprows=3, encoding='latin1')
df_material_moar.head(5)
# Out:
#    Unnamed: 0 Unnamed: 1   SOrg.    Plnt  Unnamed: 4   Material  \
# 0         NaN        NaN  8750.0  8750.0         NaN   435000.0
# 1         NaN        NaN  8750.0  8750.0         NaN  2197626.0
# 2         NaN        NaN  8750.0  8750.0         NaN  2330922.0
# 3         NaN        NaN  8750.0  8750.0         NaN  2330924.0
# 4         NaN        NaN  8750.0  8750.0         NaN  2273699.0
#
#                       Material number  X-Plant Material Status    MS  \
# 0      Hammer drill bit TE-CX 1/4"-6"                     14.0  80.0
# 1         Fastener guide X-FG B3-BT M                     14.0  33.0
# 2  Pipe shoe MP-PS L1-1 21-26 1/2" OC                     14.0  40.0
# 3    Pipe shoe MP-PS L1-1 32-37 1" OC                     14.0  40.0
# 4             Girder end cap MT-EC-90                     14.0  33.0
#
#      Gross weight  ... XYZ   Pl Safety Stock Rounding val. BUn.2 R.profile  \
# 0              50  ...   Z    X            0             1    PC      Z004
# 1             320  ...   Z  NaN            0             1    PC      Z004
# 2           1.575  ...   N  NaN            0             8    PC      Z004
# 3           1.625  ...   N  NaN            0             8    PC      Z004
# 4              31  ...   Y  NaN            0            25    PC      Z004
#
#    LS Min. dely qty Unnamed: 36 BUn.3
# 0  PK             1         NaN    PC
# 1  PK             1         NaN    PC
# 2  PK             8         NaN    PC
# 3  PK             8         NaN    PC
# 4  PK            25         NaN    PC
#
# [5 rows x 38 columns]

# %%
unnamed_columns = [col for col in df_material_moar.columns if 'Unnamed:' in col]

print("Columns with 'Unnamed:' in their title:")
for col in unnamed_columns:
    print(col)
# Out:
# Columns with 'Unnamed:' in their title:
# Unnamed: 0
# Unnamed: 1
# Unnamed: 4
# Unnamed: 36

# %%
df_material_moar.drop(columns=unnamed_columns, inplace=True)

# %%
df_material_moar.head(5)
# Out:
#     SOrg.    Plnt   Material                     Material number  \
# 0  8750.0  8750.0   435000.0      Hammer drill bit TE-CX 1/4"-6"
# 1  8750.0  8750.0  2197626.0         Fastener guide X-FG B3-BT M
# 2  8750.0  8750.0  2330922.0  Pipe shoe MP-PS L1-1 21-26 1/2" OC
# 3  8750.0  8750.0  2330924.0    Pipe shoe MP-PS L1-1 32-37 1" OC
# 4  8750.0  8750.0  2273699.0             Girder end cap MT-EC-90
#
#    X-Plant Material Status    MS    Gross weight WUn Spart   ValidFrom  ...  \
# 0                     14.0  80.0              50   G   NaN  16.01.2020  ...
# 1                     14.0  33.0             320   G     X  12.12.2023  ...
# 2                     14.0  40.0           1.575   G   NaN  01.09.2023  ...
# 3                     14.0  40.0           1.625   G   NaN  01.09.2023  ...
# 4                     14.0  33.0              31   G   NaN  01.09.2023  ...
#
#   TABCD XYZ   Pl Safety Stock Rounding val. BUn.2 R.profile  LS Min. dely qty  \
# 0     D   Z    X            0             1    PC      Z004  PK             1
# 1     D   Z  NaN            0             1    PC      Z004  PK             1
# 2     D   N  NaN            0             8    PC      Z004  PK             8
# 3     D   N  NaN            0             8    PC      Z004  PK             8
# 4     D   Y  NaN            0            25    PC      Z004  PK            25
#
#   BUn.3
# 0    PC
# 1    PC
# 2    PC
# 3    PC
# 4    PC
#
# [5 rows x 34 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
df_material_moar.head()
# Out:
#     SOrg.    Plnt   Material                     Material number  \
# 0  8750.0  8750.0   435000.0      Hammer drill bit TE-CX 1/4"-6"
# 1  8750.0  8750.0  2197626.0         Fastener guide X-FG B3-BT M
# 2  8750.0  8750.0  2330922.0  Pipe shoe MP-PS L1-1 21-26 1/2" OC
# 3  8750.0  8750.0  2330924.0    Pipe shoe MP-PS L1-1 32-37 1" OC
# 4  8750.0  8750.0  2273699.0             Girder end cap MT-EC-90
#
#    X-Plant Material Status    MS    Gross weight WUn Spart   ValidFrom  \
# 0                     14.0  80.0              50   G   NaN  16.01.2020
# 1                     14.0  33.0             320   G     X  12.12.2023
# 2                     14.0  40.0           1.575   G   NaN  01.09.2023
# 3                     14.0  40.0           1.625   G   NaN  01.09.2023
# 4                     14.0  33.0              31   G   NaN  01.09.2023
#
#   Min.order qty BUn Orig  Web FM rel.  Av  PGr  GRT Typ MRPCn Min.lot size  \
# 0             1  PC   DE    X     NaN  ZC  L09  2.0  ND   L09            1
# 1             1  PC   AT  NaN     NaN  ZC  U26  2.0  X6   U26            1
# 2             8  PC   CZ    X     NaN  ZC  L06  2.0  X6   L06            8
# 3             8  PC   CZ    X     NaN  ZC  L06  2.0  X6   L06            8
# 4            25  PC   CN    X     NaN  ZC  L14  2.0  Y1   L14           50
#
#   BUn.1 SPT   PDT TABCD XYZ   Pl Safety Stock Rounding val. BUn.2 R.profile  \
# 0    PC  4C  68.0     D   Z    X            0             1    PC      Z004
# 1    PC  4C  68.0     D   Z  NaN            0             1    PC      Z004
# 2    PC  U0  66.0     D   N  NaN            0             8    PC      Z004
# 3    PC  U0  66.0     D   N  NaN            0             8    PC      Z004
# 4    PC  4C  68.0     D   Y  NaN            0            25    PC      Z004
#
#    LS Min. dely qty BUn.3
# 0  PK             1    PC
# 1  PK             1    PC
# 2  PK             8    PC
# 3  PK             8    PC
# 4  PK            25    PC

# %%
df_material_moar.shape
# Out:
# (14837, 34)

# %%
column_titles = df_material_moar.columns.tolist()
column_titles
# Out:
# ['SOrg.',
#  'Plnt',
#  'Material',
#  'Material number',
#  'X-Plant Material Status',
#  'MS',
#  '   Gross weight',
#  'WUn',
#  'Spart',
#  'ValidFrom',
#  'Min.order qty',
#  'BUn',
#  'Orig',
#  'Web',
#  'FM rel.',
#  'Av',
#  'PGr',
#  'GRT',
#  'Typ',
#  'MRPCn',
#  'Min.lot size',
#  'BUn.1',
#  'SPT',
#  ' PDT',
#  'TABCD',
#  'XYZ',
#  'Pl',
#  'Safety Stock',
#  'Rounding val.',
#  'BUn.2',
#  'R.profile',
#  'LS',
#  'Min. dely qty',
#  'BUn.3']

# %%
new_column_titles = {col: col.strip().replace(' ', '_').replace('-', '_').replace('.','') for col in column_titles}

# %%
df_material_moar.rename(columns=new_column_titles, inplace=True)

# %%
df_material_moar.columns.tolist()
# Out:
# ['SOrg',
#  'Plnt',
#  'Material',
#  'Material_number',
#  'X_Plant_Material_Status',
#  'MS',
#  'Gross_weight',
#  'WUn',
#  'Spart',
#  'ValidFrom',
#  'Minorder_qty',
#  'BUn',
#  'Orig',
#  'Web',
#  'FM_rel',
#  'Av',
#  'PGr',
#  'GRT',
#  'Typ',
#  'MRPCn',
#  'Minlot_size',
#  'BUn1',
#  'SPT',
#  'PDT',
#  'TABCD',
#  'XYZ',
#  'Pl',
#  'Safety_Stock',
#  'Rounding_val',
#  'BUn2',
#  'Rprofile',
#  'LS',
#  'Min_dely_qty',
#  'BUn3']

# %%
column_counts = df_material_moar.columns.value_counts()
duplicate_columns = column_counts[column_counts > 1].index

# %%
for col in duplicate_columns:
    col_indices = [i for i, x in enumerate(df_material_moar.columns) if x == col]
    for j, index in enumerate(col_indices):
        df_material_moar.columns.values[index] = f"{col}_{j+1}"

# %%
df_material_moar.columns.tolist()
# Out:
# ['SOrg',
#  'Plnt',
#  'Material',
#  'Material_number',
#  'X_Plant_Material_Status',
#  'MS',
#  'Gross_weight',
#  'WUn',
#  'Spart',
#  'ValidFrom',
#  'Minorder_qty',
#  'BUn',
#  'Orig',
#  'Web',
#  'FM_rel',
#  'Av',
#  'PGr',
#  'GRT',
#  'Typ',
#  'MRPCn',
#  'Minlot_size',
#  'BUn1',
#  'SPT',
#  'PDT',
#  'TABCD',
#  'XYZ',
#  'Pl',
#  'Safety_Stock',
#  'Rounding_val',
#  'BUn2',
#  'Rprofile',
#  'LS',
#  'Min_dely_qty',
#  'BUn3']

# %%
df_material_moar['SOrg'] = df_material_moar['SOrg'].fillna(0).astype(int).astype(str).str.strip()
df_material_moar['Plnt'] = df_material_moar['Plnt'].fillna(0).astype(int).astype(str).str.strip()
df_material_moar['Material'] = df_material_moar['Material'].fillna(0).astype(int).astype(str).str.strip()
df_material_moar['Material_number'] = df_material_moar['Material_number'].astype(str).str.strip()
df_material_moar['X_Plant_Material_Status'] = df_material_moar['X_Plant_Material_Status'].fillna(0).astype(int).astype(str).str.strip()
df_material_moar['MS'] = df_material_moar['MS'].fillna(0).astype(int).astype(str).str.strip()
df_material_moar['Gross_weight'] = df_material_moar['Gross_weight'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['WUn'] = df_material_moar['WUn'].astype(str).str.strip()
df_material_moar['Spart'] = df_material_moar['Spart'].astype(str).str.strip()
df_material_moar['ValidFrom'] = pd.to_datetime(df_material_moar['ValidFrom'], errors="coerce", format='%d.%m.%Y')
df_material_moar['Minorder_qty'] = df_material_moar['Minorder_qty'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['BUn'] = df_material_moar['BUn'].astype(str).str.strip()
df_material_moar['Orig'] = df_material_moar['Orig'].astype(str).str.strip()
df_material_moar['Web'] = df_material_moar['Web'].astype(str).str.strip()
df_material_moar['FM_rel'] = df_material_moar['FM_rel'].astype(str).str.strip()
df_material_moar['Av'] = df_material_moar['Av'].astype(str).str.strip()
df_material_moar['PGr'] = df_material_moar['PGr'].astype(str).str.strip()
df_material_moar['GRT'] = df_material_moar['GRT'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['Typ'] = df_material_moar['Typ'].astype(str).str.strip()
df_material_moar['MRPCn'] = df_material_moar['MRPCn'].astype(str).str.strip()
df_material_moar['Minlot_size'] = df_material_moar['Minlot_size'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['BUn1'] = df_material_moar['BUn1'].astype(str).str.strip()
df_material_moar['SPT'] = df_material_moar['SPT'].astype(str).str.strip()
df_material_moar['PDT'] = df_material_moar['PDT'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['TABCD'] = df_material_moar['TABCD'].astype(str).str.strip()
df_material_moar['XYZ'] = df_material_moar['XYZ'].astype(str).str.strip()
df_material_moar['Pl'] = df_material_moar['Pl'].astype(str).str.strip()
df_material_moar['Safety_Stock'] = df_material_moar['Safety_Stock'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['Rounding_val'] = df_material_moar['Rounding_val'].astype(str).str.strip()
df_material_moar['BUn2'] = df_material_moar['BUn2'].astype(str).str.strip()
df_material_moar['Rprofile'] = df_material_moar['Rprofile'].astype(str).str.strip()
df_material_moar['LS'] = df_material_moar['LS'].astype(str).str.strip()
df_material_moar['Min_dely_qty'] = df_material_moar['Min_dely_qty'].fillna(0).astype(str).str.strip().str.replace('.', '').str.replace(',', '.').astype(float)
df_material_moar['BUn3'] = df_material_moar['BUn3'].astype(str).str.strip()

# %%
df_material_moar['key_material'] = df_material_moar['SOrg'] + '/' + df_material_moar['Material']
df_material_moar['key_material'] = df_material_moar['key_material'].astype(str).str.strip()

# %%
material_8750_preprocessed_path
# Out:
# 'c:\\Users\\sepujas\\Dev\\mat2\\data\\preprocessed\\tbl_material_8750.csv'

# %%
df_material_moar.to_csv(material_8750_preprocessed_path, index=False, encoding='latin1')

# %%
df_material_moar.dtypes
# Out:
# SOrg                               object
# Plnt                               object
# Material                           object
# Material_number                    object
# X_Plant_Material_Status            object
# MS                                 object
# Gross_weight                      float64
# WUn                                object
# Spart                              object
# ValidFrom                  datetime64[ns]
# Minorder_qty                      float64
# BUn                                object
# Orig                               object
# Web                                object
# FM_rel                             object
# Av                                 object
# PGr                                object
# GRT                               float64
# Typ                                object
# MRPCn                              object
# Minlot_size                       float64
# BUn1                               object
# SPT                                object
# PDT                               float64
# TABCD                              object
# XYZ                                object
# Pl                                 object
# Safety_Stock                      float64
# Rounding_val                       object
# BUn2                               object
# Rprofile                           object
# LS                                 object
# Min_dely_qty                      float64
# BUn3                               object
# key_material                       object
# dtype: object
